# %%
class student:
    def __init__(self,name,marks,rollno):
        self.name=name
        self.marks=marks
        self.rollno=rollno
    def display_student(self):
        print("Name:",self.name)
        print("Marks:",self.marks)
        print("Roll No:",self.rollno)
    def calculate_grade(self):
        if self.marks>=90:
            return "A"
        elif self.marks>=80:
            return "B"
        elif self.marks>=70:
            return "C"
        elif self.marks>=60:
            return "D"
        else:
            return "F"

abid = student("Abid", 85, 101)
abid.display_student()
abids_grade = abid.calculate_grade()
print("Grade:", abids_grade)
# Out:
# Name: Abid
# Marks: 85
# Roll No: 101
# Grade: B

# %%
class car:
    def __init__(self,brand,model,year):
        self.brand=brand
        self.model=model
        self.year=year

    def start_engine(self):
        print(f"The engine of {self.year} {self.brand} {self.model} is starting.")
    def stop_engine(self):
        print(f"The engine of {self.year} {self.brand} {self.model} is stopping.")
    def display_info(self):
        print("Car Brand:",self.brand)
        print("Car Model:",self.model)
        print("Car Year:",self.year)

bmw = car("BMW", "X5", 2022)
bmw.display_info()
bmw.start_engine()
bmw.stop_engine()
# Out:
# Car Brand: BMW
# Car Model: X5
# Car Year: 2022
# The engine of 2022 BMW X5 is starting.
# The engine of 2022 BMW X5 is stopping.

# %%
class Rectangle:
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        return self.length*self.width
    def perimeter(self):
        return 2*(self.length+self.width)

rect = Rectangle(5, 3)
print("Area of Rectangle:", rect.area())
print("Perimeter of Rectangle:", rect.perimeter())
# Out:
# Area of Rectangle: 15
# Perimeter of Rectangle: 16

# %%
class bank_account:
    def __init__ (self,account_number,account_holder,balance):
        self.account_number=account_number
        self.account_holder=account_holder
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print(f"Deposited {amount}. New balance is {self.balance}.")

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient balance.")
        else:
            self.balance-=amount
            print(f"Withdrew {amount}. New balance is {self.balance}.")
    def display_account_info(self):
        print("Account Number:",self.account_number)
        print("Account Holder:",self.account_holder)
        print("Balance:",self.balance)

abid = bank_account("123456789", "Abid", 1000)
abid.display_account_info()
abid.deposit(500)
abid.withdraw(200)
abid.withdraw(2000)
abid.display_account_info()
# Out:
# Account Number: 123456789
# Account Holder: Abid
# Balance: 1000
# Deposited 500. New balance is 1500.
# Withdrew 200. New balance is 1300.
# Insufficient balance.
# Account Number: 123456789
# Account Holder: Abid
# Balance: 1300

# %%
class employee:
    def __init__ (self,name,position,salary):
        self.name=name
        self.position=position
        self.salary=salary
    def display_employee_info(self):
        print("Employee Name:",self.name)
        print("Position:",self.position)
        print("Salary:",self.salary)
    def calculate_annual_salary(self):
        return self.salary*12
    
emp = employee("Abid", "Software Engineer", 5000)
emp.display_employee_info()
annual_salary = emp.calculate_annual_salary()
print("Annual Salary:", annual_salary)
# Out:
# Employee Name: Abid
# Position: Software Engineer
# Salary: 5000
# Annual Salary: 60000

# %%
class book:
    def __init__(self,title,author,available=True):
        self.title=title
        self.author=author
        self.available=available
    def issue_book(self):
        if self.available:
            self.available=False
            print(f"The book '{self.title}' by {self.author} has been issued.")
        else:
            print(f"The book '{self.title}' by {self.author} is currently unavailable.")
    def return_book(self):
        if not self.available:
            self.available=True
            print(f"The book '{self.title}' by {self.author} has been returned.")
        else:
            print(f"The book '{self.title}' by {self.author} was not issued.")
    def book_availability(self):
        if self.available:
            print(f"The book '{self.title}' by {self.author} is available.")
        else:
            print(f"The book '{self.title}' by {self.author} is currently unavailable.")
book1 = book("The Great Gatsby", "F. Scott Fitzgerald")
book1.issue_book()
book1.book_availability()
book2 = book("The Great Gatsby", "F. Scott Fitzgerald")
book2.issue_book()
book1.return_book()
book1.book_availability()
# Out:
# The book 'The Great Gatsby' by F. Scott Fitzgerald has been issued.
# The book 'The Great Gatsby' by F. Scott Fitzgerald is currently unavailable.
# The book 'The Great Gatsby' by F. Scott Fitzgerald has been issued.
# The book 'The Great Gatsby' by F. Scott Fitzgerald has been returned.
# The book 'The Great Gatsby' by F. Scott Fitzgerald is available.

# %%
class ShoppingCart:
    def __init__(self):
        self.items = []
        self.prices = {}
    def add_item(self, item, price):
        self.items.append(item)
        self.prices[item] = price
        print(f"Added {item} to the shopping cart.")
    def remove_item(self,item, price):
        if item in self.items:
            self.items.remove(item)
            del self.prices[item]
            print(f"Removed {item} from the shopping cart.")
        else:
            print(f"{item} is not in the shopping cart.")
    def view_cart(self):
        if self.items:
            print("Items in the shopping cart:")
            for item in self.items:
                print("-", item)
        else:
            print("The shopping cart is empty.")
    def calculate_total(self):
        total = sum(self.prices[item] for item in self.items)
        print(f"Total cost: ${total:.2f}")
art = ShoppingCart()
art.add_item("Laptop", 999.99)
art.view_cart()
art.calculate_total()
art.add_item("Mouse", 25.50)
art.view_cart()
art.calculate_total()
art.remove_item("Laptop", 999.99)
art.view_cart()
art.calculate_total()
# Out:
# Added Laptop to the shopping cart.
# Items in the shopping cart:
# - Laptop
# Total cost: $999.99
# Added Mouse to the shopping cart.
# Items in the shopping cart:
# - Laptop
# - Mouse
# Total cost: $1025.49
# Removed Laptop from the shopping cart.
# Items in the shopping cart:
# - Mouse
# Total cost: $25.50

# %%
class ATM:
    def __init__(self,pin,balance):
        self.pin=pin
        self.balance=balance

    def verify_pin(self,entered_pin):
        return self.pin==entered_pin
    
abid_atm = ATM("1234", 1000)
abcd_pin = input("Enter your ATM PIN: ")
if abid_atm.verify_pin(abcd_pin):
    print("PIN verified successfully.")
    print(f"Your current balance is: ${abid_atm.balance:.2f}")
# Out:
# PIN verified successfully.
# Your current balance is: $1000.00

# %%
class Animal:
    def eat(self):
        print("The animal is eating.")
    def sleep(self):
        print("The animal is sleeping.")

class dog(Animal):
    def bark(self):
        print("The dog is barking.")

bruno = dog()
bruno.eat()
bruno.sleep()
bruno.bark()
# Out:
# The animal is eating.
# The animal is sleeping.
# The dog is barking.

# %%
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display_info(self):
        print("Name:",self.name)
        print("Age:",self.age)
class teacher(person):
    def __init__(self,name,age,subject):
        super().__init__(name,age)
        self.subject=subject
    def display_teacher_info(self):
        self.display_info()
        print("Subject:",self.subject)

abid = teacher("Abid", 30, "Mathematics")
abid.display_teacher_info()
abid.display_info
ali = person("Ali", 25)
ali.display_info()
# Out:
# Name: Abid
# Age: 30
# Subject: Mathematics
# Name: Ali
# Age: 25

# %%
class employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
    def display_employee_info(self):
        print("Employee Name:",self.name)
        print("Salary:",self.salary)
    
class manager(employee):
    def __init__(self,name,salary,department,team_size):
        super().__init__(name,salary)
        self.department=department
        self.team_size=team_size
    def display_manager_info(self):
        self.display_employee_info()
        print("Department:",self.department)
        print("Team Size:",self.team_size)

hamza = manager("Hamza", 8000, "Sales", 10)
hamza.display_manager_info()
# Out:
# Employee Name: Hamza
# Salary: 8000
# Department: Sales
# Team Size: 10

# %%
class payment:
    def __init__(self,amount):
        self.amount=amount
    def process_payment(self):
        print(f"Processing payment of ${self.amount:.2f}.")

class credit_card_payment(payment):
    def __init__(self,amount):
        super().__init__(amount)
    def process_payment(self):
        super().process_payment()
        print("Payment processed using credit card.")
class paypal_payment(payment):
    def __init__(self,payment):
        super().__init__(payment.amount)
    def process_payment(self):
        super().process_payment()
        print("Payment processed using PayPal.")
class bank_transfer_payment(payment):
    def __init__(self,payment):
        super().__init__(payment.amount)
    def process_payment(self):
        super().process_payment()
        print("Payment processed using bank transfer.")

payment1 = payment(100.00)
card = credit_card_payment(25)
card.process_payment()
paypal = paypal_payment(100)
paypal.process_payment()
# Out:
# Processing payment of $25.00.
# Payment processed using credit card.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 29
#      27 card = credit_card_payment(25)
#      28 card.process_payment()
# ---> 29 paypal = paypal_payment(100)
#      30 paypal.process_payment()
#
# Cell In[9], line 15, in paypal_payment.__init__(self, payment)
#      14 def __init__(self,payment):
# ---> 15     super().__init__(payment.amount)
#
# AttributeError: 'int' object has no attribute 'amount'

# %%
# class products:
#     def __init__(self, name, price):
#         self.name = name
#         self.price = price

#     def display_product_info(self):
#         print("Product Name:", self.name)
#         print("Price:", self.price)
class customer:
    def __init__(self, name, email):
        self.name = name
        self.email = email

    def display_customer_info(self):
        print("Customer Name:", self.name)
        print("Email:", self.email)

class order(customer):
    def __init__(self,customer_name, customer_email):
        customer.__init__(self, customer_name, customer_email)
    products = []
    def add_product(self, product_name, product_price):
        self.products.append((product_name, product_price))

    def display_order_info(self):
        for product_name, product_price in self.products:
            print("Product Name:", product_name)
            print("Price:", product_price)
        self.display_customer_info()
    def calculate_total(self):
        total = sum(product_price for _, product_price in self.products)
        print(f"Total Order Cost: ${total:.2f}")

order1 = order("Abid", "abid@example.com")
order1.add_product("Laptop", 999.99)
order1.add_product("Mouse", 25.50)
order1.display_order_info()
order1.calculate_total()
# Out:
# Product Name: Laptop
# Price: 999.99
# Product Name: Mouse
# Price: 25.5
# Customer Name: Abid
# Email: abid@example.com
# Total Order Cost: $1025.49

# %%
class patient:
    def __init__(self, name, age, medical_history):
        self.name = name
        self.age = age
        self.medical_history = medical_history
    def display_patient_info(self):
        print("Patient Name:", self.name)
        print("Age:", self.age)
        print("Medical History:", self.medical_history)

class doctor:
    def __init__(self, name, specialization):
        self.name = name
        self.specialization = specialization
    def display_doctor_info(self):
        print("Doctor Name:", self.name)
        print("Specialization:", self.specialization)

class appointment:
    def __init__(self, patient, doctor, date):
        self.patient = patient
        self.doctor = doctor
        self.date = date
    def display_appointment_info(self):
        print("Appointment Date:", self.date)
        self.patient.display_patient_info()
        self.doctor.display_doctor_info()

abdul = patient("Abdul", 45, "Diabetes")
dr_smith = doctor("Dr. Smith", "Endocrinology")
appointment1 = appointment(abdul, dr_smith, "2023-10-15")
appointment1.display_appointment_info()
# Out:
# Appointment Date: 2023-10-15
# Patient Name: Abdul
# Age: 45
# Medical History: Diabetes
# Doctor Name: Dr. Smith
# Specialization: Endocrinology

# %%
class Student:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade

    def display_student_info(self):
        print("Student Name:", self.name)
        print("Age:", self.age)
        print("Grade:", self.grade)

class Course:
    def __init__(self, course_name, Instructor):
        self.course_name = course_name
        self.instructor = Instructor
        self.students = []

    def add_student(self, student):
        self.students.append(student)

    def display_course_info(self):
        print("Course Name:", self.course_name)
        print("Instructor:", self.instructor)
        print("Enrolled Students:")
        for student in self.students:
            student.display_student_info()

class Instructor:
    def __init__(self, name, department):
        self.name = name
        self.department = department

    def display_instructor_info(self):
        print("Instructor Name:", self.name)
        print("Department:", self.department)

instructor1 = Instructor("Dr. Johnson", "Computer Science")
course1 = Course("Introduction to Programming", instructor1)
student1 = Student("Alice", 20, "A")
student2 = Student("Bob", 21, "B")
course1.add_student(student1)
course1.add_student(student2)
course1.display_course_info()
# Out:
# Course Name: Introduction to Programming
# Instructor: <__main__.Instructor object at 0x00000246AE48D010>
# Enrolled Students:
# Student Name: Alice
# Age: 20
# Grade: A
# Student Name: Bob
# Age: 21
# Grade: B

# %%
class Room:
    def __init__ (self,room_number,room_type,price_per_night):
        self.room_number = room_number
        self.room_type = room_type
        self.price_per_night = price_per_night
        self.is_available = True

    def display_room_details(self):
        print("Room Number : ",self.room_number)
        print("Room Type : ",self.room_type)
        print("Room Number : ",self.price_per_night)
        print("Room available : ",self.is_available)

class Guest:
    def __init__ (self,name,phone,gender,id_number):
        self.name = name
        self.phone = phone
        self.gender = gender
        self.id_number = id_number

    def display_guest_details(self):
        print("Guest Name : ",self.name)
        print("Guest Phone : ",self.phone)
        print("Guest Gender : ",self.gender)
        print("Guest ID Number : ",self.id_number)

class Reservation():
    def __init__ (self,reservation_id,guest,room,check_in_date,check_out_date,status):
            self.reservation_id = reservation_id
            self.guest = guest
            self.room = room
            self.check_in_date = check_in_date
            self.check_out_date = check_out_date
            self.status = status
            self.room = room
            self.guest = guest

    def check_availability(self):
         super().display_room_details()
         if not self.room.is_available:
              print('room is not available')

    def booking(self):
         if self.room ==self.room.room_number:
              if self.room.is_available:
                   print('booked successfully')
                   self.room.is_available=False

    def cancel_booking(self):
         if self.room ==self.room.room_number:
                 if not self.room.is_available:
                    print('cancelled')
                    self.room.is_available=True

# %%
class User:
    def __init__ (self,user_id,name,email):
        self.user_id= user_id
        self.name=name
        self.email=email

    def user_details(self):
        print('User Id : ',self.user_id)
        print('User Name : ',self.name)
        print('User Email : ',self.email)

class Product:
    def __init__ (self,product_id,name,price,stock):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.stock = stock

    def product_details(self):
            print('product Id : ',self.product_id)
            print('Product Name : ',self.name)
            print('Price : ',self.price)
            print('stock : ', self.stock)


class Cart:
    def __init__(self,User):
        self.user = User 
        # self.product = Product
        self.products = []
    def pr(self):
        self.user.user_details()

    def add_product(self,product):
            self.products.append(self.product)

    def all_chart_products(self):
        self.product.product_details()



user1 = User(1,'abid','abc@gmail.com')
pr = Product(1,'laptop',100,2)
mouse = Product(2,"mouse",200,5)
cart1 = Cart(user1)
product2 = Product(3,'mobile',100,2)
cart1.pr()
cart1.add_product(mouse)
cart1.all_chart_products()
# Out:
# User Id :  1
# User Name :  abid
# User Email :  abc@gmail.com
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 48
#      46 product2 = Product(3,'mobile',100,2)
#      47 cart1.pr()
# ---> 48 cart1.add_product(mouse)
#      49 cart1.all_chart_products()
#
# Cell In[2], line 35, in Cart.add_product(self, product)
#      34 def add_product(self,product):
# ---> 35         self.products.append(self.product)
#
# AttributeError: 'Cart' object has no attribute 'product'

# %%
import pandas as pd
class Dataset:
    def __init__ (self,data):
        self.data = data

    def load_data(self):
        data = pd.read_csv(self.data)
        return data

    def rows(self,data):
        rows = len(data)
        return rows

    def col(self):
            columns = self.data[1]
            return columns
    def info(self):
        return pd.info(self.data)
